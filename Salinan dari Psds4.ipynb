# %% [markdown]
# Struktur Data Tuple

# %%
#Contoh Tuple
T1 = (1, "dua", True, 1+2j)
print("ini adalah tuple", T1)
# Out:
# ini adalah tuple (1, 'dua', True, (1+2j))

# %%
T11 = 1, "dua", True, 1+2j
print("ini adalah tuple", T11)
# Out:
# ini adalah tuple (1, 'dua', True, (1+2j))

# %%
#Menampilkan tipe struktur data
type(T1)
type(T11)
# Out:
# tuple

# %% [markdown]
# Sifat-sifat tuple

# %%
#Terurut/Ordered
T1[0:3]
# Out:
# (1, 'dua', True)

# %%
#Tidak Bisa Diganti/Immutable

T1[2]="manusia"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4e4e88d585ff> in <cell line: 3>()
#       1 #Tidak Bisa Diganti/Immutable
#       2
# ----> 3 T1[2]="manusia"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#Dapat Diindeks/Slicing
print("elemen kedua dari tuple T1 adalah: ", T1[1])
# Out:
# elemen kedua dari tuple T1 adalah:  dua

# %%
#Dapat Diijinkan Duplikasi
T2 = (3, 2.4, True, 2.4)
T2
# Out:
# (3, 2.4, True, 2.4)

# %%
#tidak dapat menambahkan elemen baru T1 = (1, "dua", True, 1+2j)
print(f'tuple\t: {T1}')

T1.append(10)
T1.append(50)
print(f' tuple\t: {T1}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ceac1a6e6713> in <cell line: 2>()
#       1 #tidak dapat menambahkan elemen baru T1 = (1, "dua", True, 1+2j)
# ----> 2 print(f'tuple\t: {T1}')
#       3
#       4 T1.append(10)
#       5 T1.append(50)
#
# NameError: name 'T1' is not defined

# %%
#tidak dapat menghapus elemen
T1 = (1, "dua", True, 1+2j)
print(f' tuple\t: {T1}')

T1.remove(1)
T1.remove("dua")
print(f' tuple\t: (T1}')
# Out:
#   File "<ipython-input-3-b7ab27920091>", line 7
#     print(f' tuple\t: (T1}')
#                            ^
# SyntaxError: f-string: single '}' is not allowed

# %%
#Menggabungkan Tuple
T3 = T1+T2
T3
# Out:
# (1, 'dua', True, (1+2j), 3, 2.4, True, 2.4)

# %% [markdown]
# Latihan

# %%
T1 = (9,"dua",False,2+4j)
T2 = (13,"delapan",True,2+0j)
T1+T2
# Out:
# (9, 'dua', False, (2+4j), 13, 'delapan', True, (2+0j))

# %% [markdown]
# Struktur Data List

# %%
#Contoh List
L1 = [1, 4, 2, 13]
print(type(L1))

L2 = ["a", "Python", 3]
print(type(L2))

print(L1)
print(L2)
# Out:
# <class 'list'>
# <class 'list'>
# [1, 4, 2, 13]
# ['a', 'Python', 3]

# %%
#Sifat-sifat List

#Terurut/Ordered
print("Memanggil List L1 dengan indeks urutan:", L1[0:3])

#Bisa Diganti/Mutable
L1[1] = 2
print("List L1 setelah diganti elemennya:", L1)
L1 = [1, "dua", True, 2+3j]

#Dapat Diindeks/Slicing
print("Slicing List L1:", L1[3])

#Dapat Diijinkan Duplikasi
L1 = [1, "dua", True, 2+3j, 2+3j]
print("Duplikasi pada List L1:", L1)

#Dapat mengubah data dengan mengganti elemen tertentu
L2 = [1, "dua", True, 2+3j]
L1[2]=3
print("Data setelah diubah:", L1)

#Dapat menambahkan elemen baru pada data
L1 = [1, "dua", True, 2+3j]
L1.append(20)
print("Data setelah ditambahkan elemennya:", L1)

#Dapat menghapus elemen pada data (remove() = menghapus berdasarkan nama objek)
L1 = [1, "dua", True, 2+3j]
L1.remove(2+3j)
print("Data setelah dihapus elemennya:", L1)
# Out:
# Memanggil List L1 dengan indeks urutan: [1, 'dua', True]
# List L1 setelah diganti elemennya: [1, 2, True]
# Slicing List L1: (2+3j)
# Duplikasi pada List Li: [1, 'dua', True, (2+3j), (2+3j)]
# Data setelah diubah: [1, 'dua', 3, (2+3j), (2+3j)]
# Data setelah ditambahkan elemennya: [1, 'dua', True, (2+3j), 20]
# Data setelah dihapus elemennya: [1, 'dua', True]

# %%
#menambahkan data menggunakan fungsi extend
L1 = [1, "dua", True, 2+3j]
L1.extend("nanas")
print(L1)

L1 = [1, "dua", True, 2+3j]
L1.extend(["nanas"])
print(L1)
# Out:
# [1, 'dua', True, (2+3j), 'n', 'a', 'n', 'a', 's']
# [1, 'dua', True, (2+3j), 'nanas']

# %%
#menambahkan data menggunakan fungsi insert
L1 = [1, "dua", True, 2+3j]
L1.insert(2, 5)
print(L1)
# Out:
# [1, 'dua', 5, True, (2+3j)]

# %%
#menghapus elemen dari list menggunakan fungsi pop()
L1 = [1, "dua", True, 2+3j]
L1.pop(2)
print(L1)

L1 = [1, "dua", True, 2+3j]
L1.pop()
print(L1)
# Out:
# [1, 'dua', (2+3j)]
# [1, 'dua', True]

# %% [markdown]
# Latihan

# %%
L1 = [1,"satu",True,1+1j]
print (L1)

L1[2] = False
print (L1)

L1.append(0)
print (L1)

L1.remove(1)
print (L1)

L1.extend(["zero"])
print (L1)

L1.insert(3, 0j)
print (L1)

L1.pop(2)
print (L1)

L1.pop(0)
print (L1)
# Out:
# [1, 'satu', True, (1+1j)]
# [1, 'satu', False, (1+1j)]
# [1, 'satu', False, (1+1j), 0]
# ['satu', False, (1+1j), 0]
# ['satu', False, (1+1j), 0, 'zero']
# ['satu', False, (1+1j), 0j, 0, 'zero']
# ['satu', False, 0j, 0, 'zero']
# [False, 0j, 0, 'zero']
